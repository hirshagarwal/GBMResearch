# %%
import urllib.request, json
import requests
import os

# %%
gene_name = "NDRG4"

# %%
# URLs
fetch_samples_url = "http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,treatments[name$eq\'ISH\'],genes[acronym$eq\'{0}\'],rma::include,genes,sub_images".format(gene_name)
download_ish_url = "http://api.brain-map.org/api/v2/image_download/{0}"
download_annotation_url = "http://api.brain-map.org/api/v2/image_download/{0}?view=tumor_feature_annotation"
download_expression_url = "http://api.brain-map.org/api/v2/image_download/{0}?view=expression"

# %%
raw_json = ""
with urllib.request.urlopen(fetch_samples_url) as url:
    raw_json = json.loads(url.read().decode())
    print(raw_json)
# Out:
# {'success': True, 'id': 0, 'start_row': 0, 'num_rows': 24, 'total_rows': 24, 'msg': [{'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 265854623, 'name': None, 'plane_of_section_id': 8, 'qc_date': '2014-02-21T00:02:27Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 264632716, 'sphinx_id': 2845, 'storage_directory': '/external/gbm/prod20/image_series_265854623/', 'weight': 5040, 'genes': [{'acronym': 'NDRG4', 'alias_tags': 'BDM1 DKFZp686I1615 FLJ30586 FLJ42011 KIAA1180 MGC19632 SMAP8 SMAP-8', 'chromosome_id': 9, 'ensembl_id': None, 'entrez_id': 65009, 'genomic_reference_update_id': 491928275, 'homologene_id': 23228, 'id': 41533, 'legacy_ensembl_gene_id': None, 'name': 'NDRG family member 4', 'organism_id': 1, 'original_name': 'NDRG family member 4', 'original_symbol': 'NDRG4', 'reference_genome_id': None, 'sphinx_id': 128423, 'version_status': 'no change'}], 'sub_images': [{'annotated': False, 'axes': None, 'bits_per_component': 8, 'data_set_id': 265854623, 'expression': None, 'expression_path': '/external/gbm/prod16/0534334072/0534334072_expression.aff', 'failed': False, 'height': 18080, 'id': 265854625, 'image_height': 45184, 'image_type': 'Primary', 'image_width': 89632, 'isi_experiment_id': None, 'lims1_id': None, 'number_of_components': 3, 'ophys_experiment_id': None, 'path': '/external/gbm/prod16/0534334072/0534334072.aff', 'projection_function': None, 'resolution': 0.4994, 'section_number': 6, 'specimen_id': None, 'structure_id': None, 'tier_count': 10, 'width': 15040, 'x': 65120, 'y': 23072}]}, {'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 265859820, 'name': None, 'plane_of_section_id': 7, 'qc_date': '2014-02-21T00:03:10Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 264967627, 'sphinx_id': 10923, 'storage_directory': '/external/gbm/prod20/image_series_265859820/', 'weight': 5040, 'genes': [{'acronym': 'NDRG4', 'alias_tags': 'BDM1 DKFZp686I1615 FLJ30586 FLJ42011 KIAA1180 MGC19632 SMAP8 SMAP-8', 'chromosome_id': 9, 'ensembl_id': None, 'entrez_id': 65009, 'genomic_reference_update_id': 491928275, 'homologene_id': 23228, 'id': 41533, 'legacy_ensembl_gene_id': None, 'name': 'NDRG family member 4', 'organism_id': 1, 'original_name': 'NDRG family member 4', 'original_symbol': 'NDRG4', 'reference_genome_id': None, 'sphinx_id': 128423, 'version_status': 'no change'}], 'sub_images': [{'annotated': False, 'axes': None, 'bits_per_component': 8, 'data_set_id': 265859820, 'expression': None, 'expression_path': '/external/gbm/prod16/0534340714/0534340714_expression.aff', 'failed': False, 'height': 18080, 'id': 265859822, 'image_height': 45184, 'image_type': 'Primary', 'image_width': 79680, 'isi_experiment_id': None, 'lims1_id': None, 'number_of_components': 3, 'ophys_experiment_id': None, 'path': '/external/gbm/prod16/0534340714/0534340714.aff', 'projection_function': None, 'resolution': 0.4994, 'section_number': 6, 'specimen_id': None, 'structure_id': None, 'tier_count': 10, 'width': 15040, 'x': 7072, 'y': 4800}]}, {'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 265848995, 'name': None, 'plane_of_section_id': 8, 'qc_date': '2014-02-21T00:00:43Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 264632668, 'sphinx_id': 13207, 'storage_directory': '/external/gbm/prod20/image_series_265848995/', 'weight': 5040, 'genes': [{'acronym': 'NDRG4', 'alias_tags': 'BDM1 DKFZp686I1615 FLJ30586 FLJ42011 KIAA1180 MGC19632 SMAP8 SMAP-8', 'chromosome_id': 9, 'ensembl_id': None, 'entrez_id': 65009, 'genomic_reference_update_id': 491928275, 'homologene_id': 23228, 'id': 41533, 'legac ...

# %%
specimen_data = []
for specimen in raw_json["msg"]:
    data_tuple = (specimen["specimen_id"], specimen["sub_images"][0]["id"])
    specimen_data.append(data_tuple)
print("Downloading: {0} samples".format(len(specimen_data)))
for (specimen_id, image_id) in specimen_data:
    existing_files = os.listdir('images/auto{}'.format(gene_name))
    contains_ish = '{1}_ISH_{0}.jpg'.format(gene_name, specimen_id) in existing_files
    contains_annotation = '{1}_Annotation_{0}.jpg'.format(gene_name, specimen_id) in existing_files
    if (contains_ish & contains_annotation):
        print("Already contains: {0}".format(specimen_id))
        continue
    with open('images/auto{0}/{1}_ISH_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
        image_url = download_ish_url.format(image_id)
        print(image_url)
        f.write(requests.get(image_url).content)
    with open('images/auto{0}/{1}_Annotation_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
        image_url = download_annotation_url.format(image_id)
        print(image_url)
        f.write(requests.get(image_url).content)
#     with open('images/auto{0}/{1}_Expression_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
#         image_url = download_expression_url.format(image_id)
#         print(image_url)
#         f.write(requests.get(image_url).content)
# Out:
# Downloading: 24 samples
# http://api.brain-map.org/api/v2/image_download/265854625
# http://api.brain-map.org/api/v2/image_download/265854625?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859822
# http://api.brain-map.org/api/v2/image_download/265859822?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265848997
# http://api.brain-map.org/api/v2/image_download/265848997?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859806
# http://api.brain-map.org/api/v2/image_download/265859806?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849009
# http://api.brain-map.org/api/v2/image_download/265849009?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849026
# http://api.brain-map.org/api/v2/image_download/265849026?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854629
# http://api.brain-map.org/api/v2/image_download/265854629?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854637
# http://api.brain-map.org/api/v2/image_download/265854637?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854645
# http://api.brain-map.org/api/v2/image_download/265854645?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859798
# http://api.brain-map.org/api/v2/image_download/265859798?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859818
# http://api.brain-map.org/api/v2/image_download/265859818?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859802
# http://api.brain-map.org/api/v2/image_download/265859802?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849017
# http://api.brain-map.org/api/v2/image_download/265849017?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849021
# http://api.brain-map.org/api/v2/image_download/265849021?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854653
# http://api.brain-map.org/api/v2/image_download/265854653?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859810
# http://api.brain-map.org/api/v2/image_download/265859810?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854649
# http://api.brain-map.org/api/v2/image_download/265854649?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859814
# http://api.brain-map.org/api/v2/image_download/265859814?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854633
# http://api.brain-map.org/api/v2/image_download/265854633?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849005
# http://api.brain-map.org/api/v2/image_download/265849005?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849013
# http://api.brain-map.org/api/v2/image_download/265849013?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265849001
# http://api.brain-map.org/api/v2/image_download/265849001?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265859794
# http://api.brain-map.org/api/v2/image_download/265859794?view=tumor_feature_annotation
# http://api.brain-map.org/api/v2/image_download/265854641
# http://api.brain-map.org/api/v2/image_download/265854641?view=tumor_feature_annotation
