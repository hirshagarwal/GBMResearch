# %%
import urllib.request, json
import requests
import os

# %%
gene_name = "CD44"

# %%
# URLs
fetch_samples_url = "http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,treatments[name$eq\'ISH\'],genes[acronym$eq\'{0}\'],rma::include,genes,sub_images".format(gene_name)
download_ish_url = "http://api.brain-map.org/api/v2/image_download/{0}"
download_annotation_url = "http://api.brain-map.org/api/v2/image_download/{0}?view=tumor_feature_annotation"
download_expression_url = "http://api.brain-map.org/api/v2/image_download/{0}?view=expression"

# %%
raw_json = ""
with urllib.request.urlopen(fetch_samples_url) as url:
    raw_json = json.loads(url.read().decode())
    print(raw_json)
# Out:
# {'success': True, 'id': 0, 'start_row': 0, 'num_rows': 50, 'total_rows': 613, 'msg': [{'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 100122851, 'name': None, 'plane_of_section_id': 9, 'qc_date': '2010-10-08T21:31:09Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 706764, 'sphinx_id': 89048, 'storage_directory': '/external/gbm/prod24/image_series_100122851/', 'weight': 5040, 'genes': [{'acronym': 'CD44', 'alias_tags': 'CDW44 CSPG8 ECMR-III HCELL HUTCH-I IN INLU LHR MC56 MDU2 MDU3 MGC10468 MIC4 MUTCH-I Pgp1', 'chromosome_id': 4, 'ensembl_id': None, 'entrez_id': 960, 'genomic_reference_update_id': 491928275, 'homologene_id': 508, 'id': 955, 'legacy_ensembl_gene_id': None, 'name': 'CD44 molecule (Indian blood group)', 'organism_id': 1, 'original_name': 'CD44 molecule (Indian blood group)', 'original_symbol': 'CD44', 'reference_genome_id': None, 'sphinx_id': 349718, 'version_status': 'no change'}], 'sub_images': [{'annotated': False, 'axes': None, 'bits_per_component': 8, 'data_set_id': 100122851, 'expression': None, 'expression_path': '/external/gbm/prod0/0534328304/0534328304_expression.aff', 'failed': False, 'height': 18080, 'id': 101700608, 'image_height': 38080, 'image_type': 'Primary', 'image_width': 78528, 'isi_experiment_id': None, 'lims1_id': 101700608, 'number_of_components': 3, 'ophys_experiment_id': None, 'path': '/external/gbm/prod0/0534328304/0534328304.aff', 'projection_function': None, 'resolution': 0.504, 'section_number': 7, 'specimen_id': None, 'structure_id': None, 'tier_count': 10, 'width': 15040, 'x': 3968, 'y': 19616}]}, {'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 267794434, 'name': None, 'plane_of_section_id': 5, 'qc_date': '2013-09-06T17:21:34Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 267057610, 'sphinx_id': 145444, 'storage_directory': '/external/gbm/prod6/image_series_267794434/', 'weight': 5040, 'genes': [{'acronym': 'CD44', 'alias_tags': 'CDW44 CSPG8 ECMR-III HCELL HUTCH-I IN INLU LHR MC56 MDU2 MDU3 MGC10468 MIC4 MUTCH-I Pgp1', 'chromosome_id': 4, 'ensembl_id': None, 'entrez_id': 960, 'genomic_reference_update_id': 491928275, 'homologene_id': 508, 'id': 955, 'legacy_ensembl_gene_id': None, 'name': 'CD44 molecule (Indian blood group)', 'organism_id': 1, 'original_name': 'CD44 molecule (Indian blood group)', 'original_symbol': 'CD44', 'reference_genome_id': None, 'sphinx_id': 349718, 'version_status': 'no change'}], 'sub_images': [{'annotated': False, 'axes': None, 'bits_per_component': 8, 'data_set_id': 267794434, 'expression': None, 'expression_path': '/external/gbm/prod0/0534341052/0534341052_expression.aff', 'failed': False, 'height': 18080, 'id': 267794436, 'image_height': 44448, 'image_type': 'Primary', 'image_width': 85632, 'isi_experiment_id': None, 'lims1_id': None, 'number_of_components': 3, 'ophys_experiment_id': None, 'path': '/external/gbm/prod0/0534341052/0534341052.aff', 'projection_function': None, 'resolution': 0.4994, 'section_number': 22, 'specimen_id': None, 'structure_id': None, 'tier_count': 10, 'width': 15040, 'x': 43392, 'y': 3168}]}, {'blue_channel': None, 'delegate': False, 'expression': False, 'failed': False, 'failed_facet': 734881840, 'green_channel': None, 'id': 267815245, 'name': None, 'plane_of_section_id': 9, 'qc_date': '2013-09-06T17:57:44Z', 'red_channel': None, 'reference_space_id': None, 'rnaseq_design_id': None, 'section_thickness': 20.0, 'specimen_id': 267060313, 'sphinx_id': 113311, 'storage_directory': '/external/gbm/prod7/image_series_267815245/', 'weight': 5040, 'genes': [{'acronym': 'CD44', 'alias_tags': 'CDW44 CSPG8 ECMR-III HCELL HUTCH-I IN INLU LHR MC56 MDU2 MDU3 MGC10468 MIC4 MUTCH-I Pgp1', 'chromosome_id': 4, 'ensembl_id': None, 'en ...

# %%
specimen_data = []
for specimen in raw_json["msg"]:
    data_tuple = (specimen["specimen_id"], specimen["sub_images"][0]["id"])
    specimen_data.append(data_tuple)
print("Downloading: {0} samples".format(len(specimen_data)))
for (specimen_id, image_id) in specimen_data:
    existing_files = os.listdir('images/auto{}'.format(gene_name))
    contains_ish = '{1}_ISH_{0}.jpg'.format(gene_name, specimen_id) in existing_files
    contains_annotation = '{1}_Annotation_{0}.jpg'.format(gene_name, specimen_id) in existing_files
    if (contains_ish & contains_annotation):
        print("Already contains: {0}".format(specimen_id))
        continue
    with open('images/auto{0}/{1}_ISH_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
        image_url = download_ish_url.format(image_id)
        print(image_url)
        f.write(requests.get(image_url).content)
    with open('images/auto{0}/{1}_Annotation_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
        image_url = download_annotation_url.format(image_id)
        print(image_url)
        f.write(requests.get(image_url).content)
#     with open('images/auto{0}/{1}_Expression_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
#         image_url = download_expression_url.format(image_id)
#         print(image_url)
#         f.write(requests.get(image_url).content)
# Out:
# Downloading: 50 samples
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 706764
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 267057610
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 267060313
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 278438921
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 293590603
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 286737226
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 267499996
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 293487616
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 267499974
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 267499982
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 264628980
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 272982086
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 286730021
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 285041111
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 286737220
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 292829419
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 712644
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# Already contains: 264714412
# ['278438921_ISH_CD44.jpg', '264714412_Annotation_CD44.jpg', '267499996_Annotation_CD44.jpg', '267060313_ISH_CD44.jpg', '.DS_Store', '286730021_ISH_CD44.jpg', '264714412_ISH_CD44.jpg', '267057610_Annotation_CD44.jpg', '272986199_ISH_CD44.jpg', '293487616_ISH_CD44.jpg', '267499974_Annotation_CD44.jpg', '264628980_Annotation_CD44.jpg', '286737220_ISH_CD44.jpg', '293590603_Annotation_CD44.jpg', '267499982_ISH_CD44.jpg', '267057610_ISH_CD44.jpg', '293590603_ISH_CD44.jpg', '267499982_Annotation_CD44.jpg', '272982086_Annotation_CD44.jpg', '286737226_ISH_CD44.jpg', '267499996_ISH_CD44.jpg', '712644_Annotation_CD44.jpg', '285041111_Annotation_CD44.jpg', '267060313_Annotation_CD44.jpg', '706764_ISH_CD44.jpg', '712644_ISH_CD44.jpg', '264628980_ISH_CD44.jpg', '286730021_Annotation_CD44.jpg', '285041111_ISH_CD44.jpg', '286737226_Annotation_CD44.jpg', '706764_Annotation_CD44.jpg', '278438921_Annotation_CD44.jpg', '272982086_ISH_CD44.jpg', '267499974_ISH_CD44.jpg', '293487616_Annotation_CD44.jpg', '286737220_Annotation_CD44.jpg', '292829419_Annotation_CD44.jpg', '292829419_ISH_CD44.jpg']
# http://api.brain-map.org/api/v2/image_download/286613364
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-60508cb781c6> in <module>
#      15         image_url = download_ish_url.format(image_id)
#      16         print(image_url)
# ---> 17         f.write(requests.get(image_url).content)
#      18     with open('images/auto{0}/{1}_Annotation_{0}.jpg'.format(gene_name, specimen_id), 'wb') as f:
#      19         image_url = download_annotation_url.format(image_id)
#
# /usr/local/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# /usr/local/lib/python3.9/site-packages/requests/models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# /usr/local/lib/python3.9/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# /usr/local/lib/python3.9/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# /usr/local/lib/python3.9/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     765                 if self.chunk_left == 0:
#     766                     break
# --> 767                 chunk = self._handle_chunk(amt)
#     768                 decoded = self._decode(
#     769                     chunk, decode_content=decode_content, flush_decoder=False
#
# /usr/local/lib/python3.9/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     718             returned_chunk = value
#     719         else:  # amt > self.chunk_left
# --> 720             returned_chunk = self._fp._safe_read(self.chunk_left)
#     721             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     722             self.chunk_left = None
#
# /usr/local/Cellar/python@3.9/3.9.5/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _safe_read(self, amt)
#     607         IncompleteRead exception can be used to detect the problem.
#     608         """
# --> 609         data = self.fp.read(amt)
#     610         if len(data) < amt:
#     611             raise IncompleteRead(data, amt-len(data))
#
# /usr/local/Cellar/python@3.9/3.9.5/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:
