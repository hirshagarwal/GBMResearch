# %%
from skimage import data, io, filters
from skimage.color import rgb2hed, hed2rgb
from PIL import Image
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import numpy as np
Image.MAX_IMAGE_PIXELS = None

# %%
ish_image = io.imread('images/CDCP1/W31_1_1_ISH_CDCP1.jpg')

# %%
ish_split = rgb2hed(ish_image)

# %%
cmap_hema = LinearSegmentedColormap.from_list('mycmap', ['white', 'navy'])
cmap_eosin = LinearSegmentedColormap.from_list('mycmap', ['darkviolet',
                                               'white'])
cmap_dab = LinearSegmentedColormap.from_list('mycmap', ['white',
                                             'saddlebrown'])

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 6), sharex=True, sharey=True)
ax = axes.ravel()
ax[0].imshow(ish_image)
ax[1].imshow(ish_split[:, :, 0], cmap=cmap_hema)
ax[2].imshow(ish_split[:, :, 1], cmap=cmap_eosin)
ax[3].imshow(ish_split[:, :, 2], cmap=cmap_dab)

# %%
ish_mask = (ish_image[:, :, 0] > 200)
ish_filtered = ish_image * ish_mask
plt.imshow(ish_filtered)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2700502303c9> in <module>
#       1 ish_mask = (ish_image[:, :, 0] > 200)
# ----> 2 ish_filtered = ish_image * ish_mask
#       3 plt.imshow(ish_filtered)
#
# ValueError: operands could not be broadcast together with shapes (18048,15040,3) (18048,15040)

# %%
ish_mask.shape
# Out:
# (18048, 15040)
